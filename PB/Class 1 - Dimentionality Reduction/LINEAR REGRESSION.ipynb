# %% [markdown]
# # LINEAR REGRESSION SQUARE MINIMUM

# %%
import numpy as np
from numpy import random as rd
from numpy.linalg import inv
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(projection='3d')
ax.grid(False)

x = np.linspace(-1, 1, 50)
y = np.linspace(-1, 1, 50)

x, y = np.meshgrid(x, y)

z = x + y


ax.plot_surface(x, y, z, cmap='plasma')
ax.axis(False)
# Out:
# (-1.1, 1.1, -1.1, 1.1)

# %% [markdown]
# ## Generate Data

# %%
matrix = list()

for i in z:
    linha  = list()
    for j in i:
        linha.append(j + 0.5*(rd.random()-0.5))
    matrix.append(linha)

matrix = np.array(matrix)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(projection='3d')
ax.grid(False)

#ax.plot_surface(x, y, z, cmap='plasma')
ax.scatter(x, y, matrix, alpha=0.1)

# %%
# plot raw data
plt.figure()
ax = plt.subplot(111, projection='3d')
ax.scatter(x, y, matrix, alpha=0.1)

# do fit
tmp_A = []
tmp_b = []
for i in range(len(x)):
    for j in range(i):
        tmp_A.append([x[i][j], y[i][j], 1])
        tmp_b.append(matrix[i][j])
b = np.matrix(tmp_b).T
A = np.matrix(tmp_A)
fit = (A.T * A).I * A.T * b
errors = b - A * fit
residual = np.linalg.norm(errors)

print("solution:")
print("%f x + %f y + %f = z" % (fit[0], fit[1], fit[2]))
#print("errors:")
#print(errors)
#print("residual:")
#print(residual)

# plot plane
xlim = ax.get_xlim()
ylim = ax.get_ylim()
X,Y = np.meshgrid(np.arange(xlim[0], xlim[1]),
                  np.arange(ylim[0], ylim[1]))
Z = np.zeros(X.shape)
for r in range(X.shape[0]):
    for c in range(X.shape[1]):
        Z[r,c] = fit[0] * X[r,c] + fit[1] * Y[r,c] + fit[2]
ax.plot_surface(X,Y,Z, color='k')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()
# Out:
# solution:
# 0.998009 x + 1.002048 y + -0.004066 = z

# %%
import numpy as np

# %%
x = np.matrix([[1, 1, 1, 1],[-2, -1, 0, 2]])

# %%
y = np.array([2, 3, 1, -1])

# %%
(x*x.T).I*(35)
# Out:
# matrix([[9., 1.],
#         [1., 4.]])

# %%
x = np.matrix([[1, 1, 1, 1, 1], [1.0986, 1.386, 1.792, 2.302, 2.4849]])

# %%
(x.T @ x).I
# Out:
# matrix([[ 3.25195385e+14,  4.71024805e+14, -1.82794513e+15,
#           1.63015670e+15, -5.98431760e+14],
#         [ 5.27913366e+14,  1.82789390e+15, -3.74939646e+15,
#          -7.79453817e+14,  2.17304301e+15],
#         [-1.95151718e+15, -3.67516987e+15,  1.03458958e+16,
#          -2.32169898e+15, -2.39750973e+15],
#         [ 1.75650024e+15, -6.29464723e+14, -2.81235140e+15,
#           1.12280368e+15,  5.62512209e+14],
#         [-6.58091810e+14,  2.00571588e+15, -1.95620277e+15,
#           3.48192421e+14,  2.60386278e+14]])

# %%
import numpy as np

# %% [markdown]
# This watever
